# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_x=pd.read_csv("F:\Personal\Queens MMAI\MMAI 869 – Machine Learning and AI Technology\Driven Data team Assignment\Train set values.csv")
data_y=pd.read_csv("F:\Personal\Queens MMAI\MMAI 869 – Machine Learning and AI Technology\Driven Data team Assignment\Train set labels.csv")

# %%
data=pd.merge(data_x,data_y,on="id",how="inner")

# %% [markdown]
# ## Splitting the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data_x,data_y,train_size=0.7,random_state=42,stratify=data_y["status_group"])

# %% [markdown]
# ## Data Exploration

# %%
#Numerical Features Description
x_train.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  41580.000000   41580.000000  41580.000000  41580.000000  4.158000e+04
# mean   37053.095238     328.297768    670.883333     34.088923 -5.716324e+00
# std    21379.253543    3380.560532    693.624472      6.541418  2.940352e+00
# min        0.000000       0.000000    -63.000000      0.000000 -1.164944e+01
# 25%    18530.750000       0.000000      0.000000     33.097738 -8.543252e+00
# 50%    37055.500000       0.000000    374.000000     34.911885 -5.036156e+00
# 75%    55351.250000      25.000000   1322.000000     37.169114 -3.328690e+00
# max    74247.000000  350000.000000   2770.000000     40.344301 -2.000000e-08
#
#         num_private   region_code  district_code    population  \
# count  41580.000000  41580.000000   41580.000000  41580.000000
# mean       0.500000     15.198509       5.593218    180.270178
# std       14.103926     17.463795       9.575067    462.724333
# min        0.000000      1.000000       0.000000      0.000000
# 25%        0.000000      5.000000       2.000000      0.000000
# 50%        0.000000     12.000000       3.000000     27.500000
# 75%        0.000000     17.000000       5.000000    215.000000
# max     1776.000000     99.000000      80.000000  15300.000000
#
#        construction_year
# count       41580.000000
# mean         1303.064791
# std           950.851187
# min             0.000000
# 25%             0.000000
# 50%          1986.000000
# 75%          2004.000000
# max          2013.000000

# %%
#Categorical Features Description
x_train.describe(include="O")
# Out:
#        date_recorded                  funder installer wpt_name  \
# count          41580                   39034     39025    41580
# unique           346                    1611      1802    27265
# top       2011-03-17  Government Of Tanzania       DWE     none
# freq             410                    6405     12204     2546
#
#                 basin subvillage  region     lga   ward public_meeting  ...  \
# count           41580      41336   41580   41580  41580          39283  ...
# unique              9      16078      21     124   2073              2  ...
# top     Lake Victoria    Majengo  Iringa  Njombe  Igosi           True  ...
# freq             7058        364    3752    1769    222          35748  ...
#
#        payment_type water_quality quality_group quantity quantity_group  \
# count         41580         41580         41580    41580          41580
# unique            7             8             6        5              5
# top       never pay          soft          good   enough         enough
# freq          17792         35496         35496    23232          23232
#
#         source source_type source_class     waterpoint_type  \
# count    41580       41580        41580               41580
# unique      10           7            3                   7
# top     spring      spring  groundwater  communal standpipe
# freq     11944       11944        32085               19911
#
#        waterpoint_type_group
# count                  41580
# unique                     6
# top       communal standpipe
# freq                   24183
#
# [4 rows x 30 columns]

# %% [markdown]
# ## Data Processing

# %%
# making a copy of x_train and y_train. All processing will be done on the copies.

# %%
x_train_3=x_train.copy()
y_train_3=y_train.copy()

# %%
def process2(a,b):
    ## new feature processing
    for i in ["funder","installer"]:
        a[i]=a[i].str.lower()
        minor_values=a[i].value_counts(dropna=False)[a[i].value_counts(dropna=False,normalize=True).cumsum().values>0.95].index
        a[i]=a[i].apply(lambda s:"minor" if s in minor_values else s)
        grp_mode=a.groupby(by=["region"])[i].transform(lambda x: x.mode().iloc[0])
        a[i]=a[i].fillna(grp_mode)
    a["long_mod"]=a["longitude"]
    a.loc[a['long_mod'] == 0, 'long_mod'] = pd.NA
    grp_means=a.groupby(by=["region"])["long_mod"].transform("mean")
    a.long_mod=a.long_mod.fillna(grp_means)
    a["lat_mod"]=a["latitude"]
    a.loc[a['lat_mod'] <-100, 'lat_mod'] = pd.NA
    grp_means2=a.groupby(by=["region"])["lat_mod"].transform("mean")
    a.lat_mod=a.lat_mod.fillna(grp_means2)
    a["gps_height_mod"]=a["gps_height"]
    a.loc[a['gps_height_mod'] == 0, 'gps_height_mod'] = pd.NA
    grp_means3=a.groupby(by=["basin"])["gps_height_mod"].transform("mean")
    a.gps_height_mod=a.gps_height_mod.fillna(grp_means3)
    a.wpt_name=a.wpt_name.str.lower()
    x=list(a.wpt_name.value_counts()[(a.wpt_name.value_counts().values==1)].index)
    a.wpt_name=a.wpt_name.replace(x,"single")
    #subvillage
    grp_mode4=a.groupby(by=["region"])["subvillage"].transform(lambda x: x.mode().iloc[0])
    a.subvillage=a.subvillage.fillna(grp_mode4)
    y=list(a.subvillage.value_counts()[(a.subvillage.value_counts().values==1)].index)
    a.subvillage=a.subvillage.replace(y,"single")
    a.public_meeting=a.public_meeting.fillna("True")
    grp_mode5=a.groupby(by=["region"])["permit"].transform(lambda x: x.mode().iloc[0])
    a.permit=a.permit.fillna(grp_mode5)
    grp_mode6=a.groupby(by=["region"])["scheme_management"].transform(lambda x: x.mode().iloc[0])
    a.scheme_management=a.scheme_management.fillna(grp_mode6)
    a["permit"]=a["permit"].map(lambda s: "T" if s==True else("F" if s== False else "M"))
    a["public_meeting"]=a["public_meeting"].map(lambda s: "T" if s==True else("F" if s== False else "M"))
    #bin_edges=[np.min(a.gps_height)-1,0,500,1000,1500,2000,np.max(a.gps_height)]
    #bin_labels=["<0","0-500","500-1000","1000-1500","1500-2000",">2000"]
    #a["gps_height_cat"]=pd.cut(a.gps_height,bins=bin_edges,labels=bin_labels).astype("O")
    a=a.drop(["id","recorded_by","scheme_name","num_private"],axis=1)
    b=b.drop("id",axis=1)
    a["amount_tsh_cat"] = a["amount_tsh"].apply(lambda x: 0 if x == 0 else 1)
    date_format = '%Y-%m-%d'
    a["date_recorded"]=pd.to_datetime(a["date_recorded"])
    a["dsr"]=pd.to_datetime("2023-11-16")-a["date_recorded"]
    a.dsr=(a.dsr/ pd.Timedelta(seconds=86400))
    bin_edges=[np.min(a.construction_year)-1,0,1961,1971,1981,1991,2001,np.max(a.construction_year)+1]
    bin_labels=["0","0-1960","1960-70","1970-80","1980-90","1990-2000","2001-2013"]
    a["construction_year_cat"]=pd.cut(a.construction_year,bins=bin_edges,labels=bin_labels).astype("O")
    a=a.drop(["amount_tsh","date_recorded","gps_height","latitude","longitude","construction_year"],axis=1)
    a[["region_code","district_code","amount_tsh_cat"]]=a[["region_code","district_code","amount_tsh_cat"]].astype("O")
    cat=a.select_dtypes(include="O").columns
    #a[cat] = a[cat].fillna('missing')
    a[["region_code","district_code","amount_tsh_cat"]]=a[["region_code","district_code","amount_tsh_cat"]].astype("O")
    return a,b

# %%
x_train_2,y_train_2=process2(x_train_3,y_train_3)

# %%
x_train.nunique()
# Out:
# id                       41580
# amount_tsh                  93
# date_recorded              346
# funder                    1611
# gps_height                2385
# installer                 1802
# longitude                40285
# latitude                 40283
# wpt_name                 27265
# num_private                 58
# basin                        9
# subvillage               16078
# region                      21
# region_code                 27
# district_code               20
# lga                        124
# ward                      2073
# population                 948
# public_meeting               2
# recorded_by                  1
# scheme_management           12
# scheme_name               2472
# permit                       2
# construction_year           55
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# water_quality                8
# quality_group                6
# quantity                     5
# quantity_group               5
# source                      10
# source_type                  7
# source_class                 3
# waterpoint_type              7
# waterpoint_type_group        6
# dtype: int64

# %%
x_train_2.isna().sum()
# Out:
# funder                   0
# installer                0
# wpt_name                 0
# basin                    0
# subvillage               0
# region                   0
# region_code              0
# district_code            0
# lga                      0
# ward                     0
# population               0
# public_meeting           0
# scheme_management        0
# permit                   0
# extraction_type          0
# extraction_type_group    0
# extraction_type_class    0
# management               0
# management_group         0
# payment                  0
# payment_type             0
# water_quality            0
# quality_group            0
# quantity                 0
# quantity_group           0
# source                   0
# source_type              0
# source_class             0
# waterpoint_type          0
# waterpoint_type_group    0
# long_mod                 0
# lat_mod                  0
# gps_height_mod           0
# amount_tsh_cat           0
# dsr                      0
# construction_year_cat    0
# dtype: int64

# %%
x_train_2.columns
# Out:
# Index(['funder', 'installer', 'wpt_name', 'basin', 'subvillage', 'region',
#        'region_code', 'district_code', 'lga', 'ward', 'population',
#        'public_meeting', 'scheme_management', 'permit', 'extraction_type',
#        'extraction_type_group', 'extraction_type_class', 'management',
#        'management_group', 'payment', 'payment_type', 'water_quality',
#        'quality_group', 'quantity', 'quantity_group', 'source', 'source_type',
#        'source_class', 'waterpoint_type', 'waterpoint_type_group', 'long_mod',
#        'lat_mod', 'gps_height_mod', 'amount_tsh_cat', 'dsr',
#        'construction_year_cat'],
#       dtype='object')

# %%
x_test_2=x_test.copy()
y_test_2=y_test.copy()
x_test_2,y_test_2=process2(x_test_2,y_test_2)

# %%
## Categorical features encoding
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
Label_col=x_train_2.select_dtypes(include="O").columns
Or=OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
Or.fit(x_train_2[Label_col])
x_train_2[Label_col]=Or.transform(x_train_2[Label_col])
x_test_2[Label_col]=Or.transform(x_test_2[Label_col])

# %%
le=LabelEncoder()
le.fit(y_train_2["status_group"])
y_train_2["status_group"]=le.transform(y_train_2["status_group"])
y_test_2["status_group"]=le.transform(y_test_2["status_group"])

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
def matrix(xtr,ytr,xte,yte,est):
    print ("\n Train accuracy",round(accuracy_score(ytr, est.predict(xtr)),3))
    print ("\n Train Classification Report\n\n", classification_report(ytr, est.predict(xtr)))
    print ("\n Test accuracy", round(accuracy_score(yte, est.predict(xte)),3))
    print ("\n Test Classification Report\n\n", classification_report(yte, est.predict(xte)))

# %%
import xgboost as xgb

# %%
cat_col=list(x_train_2.select_dtypes(include="O").columns)
#clf = CatBoostClassifier(iterations=10, depth=5, learning_rate=0.1, loss_function='MultiClass',cat_features=cat_col)

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import GridSearchCV

# %%
y_train_2
# Out:
#        status_group
# 5974              0
# 31787             0
# 27800             0
# 8008              2
# 39725             2
# ...             ...
# 21108             1
# 14847             2
# 26579             2
# 8192              0
# 49783             0
#
# [41580 rows x 1 columns]

# %%
#cat_col=list(x_train_2.select_dtypes(include="O").columns)
#clf = CatBoostClassifier(loss_function='MultiClass',cat_features=cat_col)
#parameters={"iterations":[1000],"depth":np.arange(2,20,2),"learning_rate":np.arange(0.01,0.1,0.01),"max_bin":np.arange(10,100,5)}
#Grid=GridSearchCV(clf,param_grid=parameters,cv=5,scoring="f1_macro",n_jobs=4)

# %%
# %pip install optuna
import optuna
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
def objective_dt(trial, X, y):

  # Now, define all the hyperparams we want to vary, and what values they are allowed
  # to take.
  #
  # Each trial, optuna will automatically choose values for each hyperparam.
  hyper_params = {
        "objective":'multi:softmax',
        "n_estimators":1000,
        "max_depth":trial.suggest_int("max_depth",8,16,step=2),
        "learning_rate":trial.suggest_float("learning_rate",0.01,0.2,step=.02),
        "max_bin":trial.suggest_int("max_bin",40,200,step=20),
        "random_state": 60,
  }


  # Use the hyperparams that optuna has chosen for this trial to create a DecisionTreeClassifier
  clf_xgb = xgb.XGBClassifier(**hyper_params)

  # Run CV to see how well these hyper_params do
  cv_scores = cross_val_score(clf_xgb, X, y, cv=5, scoring="f1_macro")
  score = np.mean(cv_scores)

  # Whatever we return here tells optuna how well these parameters did
  return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(lambda trial: objective_dt(trial, x_train_2,y_train_2.values.ravel()), n_trials=100,  gc_after_trial=True)
# Out:
# [I 2023-12-10 00:36:14,310] A new study created in memory with name: no-name-e417f010-7e64-499b-8505-a69638cbb15c
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 00:43:04,542] Trial 0 finished with value: 0.6795630763110566 and parameters: {'max_depth': 16, 'learning_rate': 0.01, 'max_bin': 120}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 00:46:12,396] Trial 1 finished with value: 0.6755601309512429 and parameters: {'max_depth': 16, 'learning_rate': 0.19, 'max_bin': 200}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 00:48:55,004] Trial 2 finished with value: 0.6767054175745052 and parameters: {'max_depth': 12, 'learning_rate': 0.05, 'max_bin': 80}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 00:51:20,714] Trial 3 finished with value: 0.6794807830503709 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 180}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 00:53:31,490] Trial 4 finished with value: 0.6759005680165581 and parameters: {'max_depth': 10, 'learning_rate': 0.15000000000000002, 'max_bin': 200}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 00:56:04,846] Trial 5 finished with value: 0.6724841007004105 and parameters: {'max_depth': 14, 'learning_rate': 0.09, 'max_bin': 40}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 00:58:32,446] Trial 6 finished with value: 0.6713016684849569 and parameters: {'max_depth': 16, 'learning_rate': 0.17, 'max_bin': 40}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:00:02,533] Trial 7 finished with value: 0.6564711600945123 and parameters: {'max_depth': 8, 'learning_rate': 0.01, 'max_bin': 60}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:02:39,535] Trial 8 finished with value: 0.6723928136127197 and parameters: {'max_depth': 16, 'learning_rate': 0.15000000000000002, 'max_bin': 60}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:05:38,175] Trial 9 finished with value: 0.6759846170324323 and parameters: {'max_depth': 16, 'learning_rate': 0.13, 'max_bin': 120}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:11:07,157] Trial 10 finished with value: 0.6789329881411529 and parameters: {'max_depth': 14, 'learning_rate': 0.01, 'max_bin': 140}. Best is trial 0 with value: 0.6795630763110566.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:13:23,933] Trial 11 finished with value: 0.6797231472983729 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 140}. Best is trial 11 with value: 0.6797231472983729.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:15:35,282] Trial 12 finished with value: 0.679630615284205 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 120}. Best is trial 11 with value: 0.6797231472983729.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:17:10,778] Trial 13 finished with value: 0.679025410806021 and parameters: {'max_depth': 8, 'learning_rate': 0.06999999999999999, 'max_bin': 140}. Best is trial 11 with value: 0.6797231472983729.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:19:31,668] Trial 14 finished with value: 0.6804031547928086 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 160}. Best is trial 14 with value: 0.6804031547928086.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:22:20,465] Trial 15 finished with value: 0.6752062351167643 and parameters: {'max_depth': 12, 'learning_rate': 0.09, 'max_bin': 160}. Best is trial 14 with value: 0.6804031547928086.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:24:32,869] Trial 16 finished with value: 0.6785935342850948 and parameters: {'max_depth': 10, 'learning_rate': 0.11, 'max_bin': 160}. Best is trial 14 with value: 0.6804031547928086.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:26:10,751] Trial 17 finished with value: 0.6788366361702539 and parameters: {'max_depth': 8, 'learning_rate': 0.03, 'max_bin': 100}. Best is trial 14 with value: 0.6804031547928086.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:30:20,479] Trial 18 finished with value: 0.6751622129406541 and parameters: {'max_depth': 12, 'learning_rate': 0.06999999999999999, 'max_bin': 160}. Best is trial 14 with value: 0.6804031547928086.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:32:51,523] Trial 19 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:37:22,589] Trial 20 finished with value: 0.6770259231230782 and parameters: {'max_depth': 14, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:39:52,989] Trial 21 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:43:34,862] Trial 22 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:45:19,817] Trial 23 finished with value: 0.6784833645713182 and parameters: {'max_depth': 8, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:48:25,398] Trial 24 finished with value: 0.6781347419429162 and parameters: {'max_depth': 12, 'learning_rate': 0.06999999999999999, 'max_bin': 200}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:50:58,622] Trial 25 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:55:24,998] Trial 26 finished with value: 0.6783106360783624 and parameters: {'max_depth': 12, 'learning_rate': 0.01, 'max_bin': 200}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:57:05,305] Trial 27 finished with value: 0.6773305119078366 and parameters: {'max_depth': 8, 'learning_rate': 0.11, 'max_bin': 180}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 01:59:27,101] Trial 28 finished with value: 0.6814437147809691 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 140}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 02:03:47,568] Trial 29 finished with value: 0.6750021012522683 and parameters: {'max_depth': 12, 'learning_rate': 0.01, 'max_bin': 100}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 02:06:12,192] Trial 30 finished with value: 0.677104683726282 and parameters: {'max_depth': 10, 'learning_rate': 0.06999999999999999, 'max_bin': 160}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 02:08:19,980] Trial 31 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 19 with value: 0.6816606537861235.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 02:10:52,824] Trial 32 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 02:12:44,742] Trial 33 finished with value: 0.6590948158199759 and parameters: {'max_depth': 8, 'learning_rate': 0.01, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 02:15:05,774] Trial 34 finished with value: 0.6816066944257508 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 02:18:29,309] Trial 35 finished with value: 0.6779044724333889 and parameters: {'max_depth': 12, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 02:22:35,412] Trial 36 finished with value: 0.6816066944257508 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 02:50:26,975] Trial 37 finished with value: 0.6774153529323041 and parameters: {'max_depth': 12, 'learning_rate': 0.09, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 03:07:14,670] Trial 38 finished with value: 0.676584936745517 and parameters: {'max_depth': 8, 'learning_rate': 0.19, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 03:34:27,926] Trial 39 finished with value: 0.6698199025743025 and parameters: {'max_depth': 10, 'learning_rate': 0.01, 'max_bin': 160}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 03:55:43,526] Trial 40 finished with value: 0.6816066944257508 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 04:14:26,773] Trial 41 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 04:37:22,364] Trial 42 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 04:54:05,016] Trial 43 finished with value: 0.6712502003735268 and parameters: {'max_depth': 10, 'learning_rate': 0.01, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 05:13:04,640] Trial 44 finished with value: 0.68107750847825 and parameters: {'max_depth': 8, 'learning_rate': 0.05, 'max_bin': 160}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 05:35:35,897] Trial 45 finished with value: 0.6781347419429162 and parameters: {'max_depth': 12, 'learning_rate': 0.06999999999999999, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 05:49:42,238] Trial 46 finished with value: 0.6814437147809691 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 140}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 06:09:54,023] Trial 47 finished with value: 0.6712502003735268 and parameters: {'max_depth': 10, 'learning_rate': 0.01, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 06:20:25,486] Trial 48 finished with value: 0.68107750847825 and parameters: {'max_depth': 8, 'learning_rate': 0.05, 'max_bin': 160}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 06:36:01,481] Trial 49 finished with value: 0.6766872411095983 and parameters: {'max_depth': 10, 'learning_rate': 0.13, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 06:49:17,414] Trial 50 finished with value: 0.6756704116690636 and parameters: {'max_depth': 12, 'learning_rate': 0.17, 'max_bin': 100}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 07:08:14,017] Trial 51 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 07:25:39,350] Trial 52 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 07:45:06,683] Trial 53 finished with value: 0.6825154045443207 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 160}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 08:03:09,367] Trial 54 finished with value: 0.6804031547928086 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 160}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 08:18:22,027] Trial 55 finished with value: 0.6705068289213392 and parameters: {'max_depth': 10, 'learning_rate': 0.01, 'max_bin': 60}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 08:31:26,405] Trial 56 finished with value: 0.6812302461645886 and parameters: {'max_depth': 8, 'learning_rate': 0.05, 'max_bin': 120}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 08:59:01,522] Trial 57 finished with value: 0.6779044724333889 and parameters: {'max_depth': 12, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 09:32:49,593] Trial 58 finished with value: 0.6803132266035675 and parameters: {'max_depth': 14, 'learning_rate': 0.01, 'max_bin': 160}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 09:46:39,381] Trial 59 finished with value: 0.6761266348815833 and parameters: {'max_depth': 10, 'learning_rate': 0.06999999999999999, 'max_bin': 140}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 10:01:49,177] Trial 60 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 10:20:41,906] Trial 61 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 10:39:08,173] Trial 62 finished with value: 0.6816066944257508 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 10:56:46,681] Trial 63 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 11:19:46,727] Trial 64 finished with value: 0.6725787639925709 and parameters: {'max_depth': 10, 'learning_rate': 0.01, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 11:34:44,775] Trial 65 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 11:44:38,139] Trial 66 finished with value: 0.6816747962647557 and parameters: {'max_depth': 8, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 11:59:37,419] Trial 67 finished with value: 0.6816747962647557 and parameters: {'max_depth': 8, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 12:11:16,392] Trial 68 finished with value: 0.6590948158199759 and parameters: {'max_depth': 8, 'learning_rate': 0.01, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 12:23:34,935] Trial 69 finished with value: 0.6814698197872138 and parameters: {'max_depth': 8, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 12:42:11,666] Trial 70 finished with value: 0.6781347419429162 and parameters: {'max_depth': 12, 'learning_rate': 0.06999999999999999, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 12:51:23,383] Trial 71 finished with value: 0.6816747962647557 and parameters: {'max_depth': 8, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 13:01:18,879] Trial 72 finished with value: 0.6816747962647557 and parameters: {'max_depth': 8, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 13:11:28,306] Trial 73 finished with value: 0.6816747962647557 and parameters: {'max_depth': 8, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 13:21:30,178] Trial 74 finished with value: 0.6590948158199759 and parameters: {'max_depth': 8, 'learning_rate': 0.01, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 13:33:25,137] Trial 75 finished with value: 0.6816747962647557 and parameters: {'max_depth': 8, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 13:51:14,825] Trial 76 finished with value: 0.6816066944257508 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 14:01:36,125] Trial 77 finished with value: 0.6814698197872138 and parameters: {'max_depth': 8, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 14:17:31,332] Trial 78 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 14:31:29,088] Trial 79 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 14:49:43,259] Trial 80 finished with value: 0.6725787639925709 and parameters: {'max_depth': 10, 'learning_rate': 0.01, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 15:03:34,628] Trial 81 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 15:19:19,776] Trial 82 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 15:35:27,686] Trial 83 finished with value: 0.6816066944257508 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 15:54:02,094] Trial 84 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 16:10:24,371] Trial 85 finished with value: 0.6725787639925709 and parameters: {'max_depth': 10, 'learning_rate': 0.01, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 16:29:10,406] Trial 86 finished with value: 0.6816606537861235 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 16:59:58,882] Trial 87 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 17:37:24,510] Trial 88 finished with value: 0.6725787639925709 and parameters: {'max_depth': 10, 'learning_rate': 0.01, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 18:07:57,726] Trial 89 finished with value: 0.6816066944257508 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 18:59:29,738] Trial 90 finished with value: 0.6762110998204135 and parameters: {'max_depth': 16, 'learning_rate': 0.03, 'max_bin': 80}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 19:28:27,092] Trial 91 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 19:58:36,973] Trial 92 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 20:27:45,424] Trial 93 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 21:01:20,744] Trial 94 finished with value: 0.6816066944257508 and parameters: {'max_depth': 10, 'learning_rate': 0.05, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 21:26:59,680] Trial 95 finished with value: 0.6782343434124306 and parameters: {'max_depth': 10, 'learning_rate': 0.13, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 21:53:13,713] Trial 96 finished with value: 0.6762900467571357 and parameters: {'max_depth': 10, 'learning_rate': 0.09, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 22:29:51,653] Trial 97 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 23:11:43,218] Trial 98 finished with value: 0.6785613421443728 and parameters: {'max_depth': 12, 'learning_rate': 0.01, 'max_bin': 180}. Best is trial 32 with value: 0.6827792543973892.
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [0.01, 0.2] and step=0.02, but the range is not divisible by `step`. It will be replaced by [0.01, 0.19].
#   warnings.warn(
# [I 2023-12-10 23:41:23,799] Trial 99 finished with value: 0.6827792543973892 and parameters: {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}. Best is trial 32 with value: 0.6827792543973892.

# %%
study.best_params
# Out:
# {'max_depth': 10, 'learning_rate': 0.03, 'max_bin': 200}

# %%
clf_xg=xgb.XGBClassifier(objective='multi:softmax',n_estimators=1000,learning_rate=0.06999999999999999,max_depth=12,max_bin=120,num_class=3)

# %%
clf_xg.fit(x_train_2,y_train_2)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.06999999999999999,
#               max_bin=120, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=12, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=None, num_class=3,
#               num_parallel_tree=None, objective='multi:softmax', ...)

# %%
cv_scores = cross_val_score(clf_xg, x_train_2, y_train_2, cv=5, scoring="accuracy")

# %%
cv_scores.mean()
# Out:
# 0.7965367965367965

# %%
matrix(x_train_2,y_train_2,x_test_2,y_test_2,clf_xg)
# Out:
#  Train accuracy 1.0
#
#  Train Classification Report
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     22581
#            1       1.00      1.00      1.00      3022
#            2       1.00      1.00      1.00     15977
#
#     accuracy                           1.00     41580
#    macro avg       1.00      1.00      1.00     41580
# weighted avg       1.00      1.00      1.00     41580
#
#
#  Test accuracy 0.803
#
#  Test Classification Report
#
#                precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84      9678
#            1       0.55      0.32      0.41      1295
#            2       0.82      0.79      0.81      6847
#
#     accuracy                           0.80     17820
#    macro avg       0.73      0.66      0.68     17820
# weighted avg       0.80      0.80      0.80     17820

# %%
Target_x=pd.read_csv("F:\Personal\Queens MMAI\MMAI 869 – Machine Learning and AI Technology\Driven Data team Assignment\Test set values.csv")

# %%
Target_x
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 0      50785         0.0    2013-02-04                    Dmdd        1996
# 1      51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2      17168         0.0    2013-02-01                     NaN        1567
# 3      45559         0.0    2013-01-22              Finn Water         267
# 4      49871       500.0    2013-03-27                  Bruder        1260
# ...      ...         ...           ...                     ...         ...
# 14845  39307         0.0    2011-02-24                  Danida          34
# 14846  18990      1000.0    2011-03-21                    Hiap           0
# 14847  28749         0.0    2013-03-04                     NaN        1476
# 14848  33492         0.0    2013-02-18                 Germany         998
# 14849  68707         0.0    2013-02-13  Government Of Tanzania         481
#
#         installer  longitude   latitude                 wpt_name  num_private  \
# 0            DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 1             DWE  36.656709  -3.309214                  Kimnyak            0
# 2             NaN  34.767863  -5.004344           Puma Secondary            0
# 3      FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 4          BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
# ...           ...        ...        ...                      ...          ...
# 14845          Da  38.852669  -6.582841                Kwambwezi            0
# 14846        HIAP  37.451633  -5.350428         Bonde La Mkondoa            0
# 14847         NaN  34.739804  -4.585587                  Bwawani            0
# 14848         DWE  35.432732 -10.584159                 Kwa John            0
# 14849  Government  34.765054 -11.226012         Kwa Mzee Chagala            0
#
#        ... payment_type water_quality quality_group      quantity  \
# 0      ...    never pay          soft          good      seasonal
# 1      ...    never pay          soft          good  insufficient
# 2      ...    never pay          soft          good  insufficient
# 3      ...      unknown          soft          good           dry
# 4      ...      monthly          soft          good        enough
# ...    ...          ...           ...           ...           ...
# 14845  ...    never pay          soft          good        enough
# 14846  ...     annually         salty         salty  insufficient
# 14847  ...    never pay          soft          good  insufficient
# 14848  ...    never pay          soft          good  insufficient
# 14849  ...    never pay          soft          good           dry
#
#        quantity_group                source           source_type  \
# 0            seasonal  rainwater harvesting  rainwater harvesting
# 1        insufficient                spring                spring
# 2        insufficient  rainwater harvesting  rainwater harvesting
# 3                 dry          shallow well          shallow well
# 4              enough                spring                spring
# ...               ...                   ...                   ...
# 14845          enough                 river            river/lake
# 14846    insufficient          shallow well          shallow well
# 14847    insufficient                   dam                   dam
# 14848    insufficient                 river            river/lake
# 14849             dry                spring                spring
#
#        source_class     waterpoint_type waterpoint_type_group
# 0           surface               other                 other
# 1       groundwater  communal standpipe    communal standpipe
# 2           surface               other                 other
# 3       groundwater               other                 other
# 4       groundwater  communal standpipe    communal standpipe
# ...             ...                 ...                   ...
# 14845       surface  communal standpipe    communal standpipe
# 14846   groundwater           hand pump             hand pump
# 14847       surface  communal standpipe    communal standpipe
# 14848       surface  communal standpipe    communal standpipe
# 14849   groundwater  communal standpipe    communal standpipe
#
# [14850 rows x 40 columns]

# %%
Target1=Target_x.copy()

# %%
def process_target2(a):
    ## new feature processing
    for i in ["funder","installer"]:
        a[i]=a[i].str.lower()
        minor_values=a[i].value_counts(dropna=False)[a[i].value_counts(dropna=False,normalize=True).cumsum().values>0.95].index
        a[i]=a[i].apply(lambda s:"minor" if s in minor_values else s)
        grp_mode=a.groupby(by=["region"])[i].transform(lambda x: x.mode().iloc[0])
        a[i]=a[i].fillna(grp_mode)
    a["long_mod"]=a["longitude"]
    a.loc[a['long_mod'] == 0, 'long_mod'] = pd.NA
    grp_means=a.groupby(by=["region"])["long_mod"].transform("mean")
    a.long_mod=a.long_mod.fillna(grp_means)
    a["lat_mod"]=a["latitude"]
    a.loc[a['lat_mod'] <-100, 'lat_mod'] = pd.NA
    grp_means2=a.groupby(by=["region"])["lat_mod"].transform("mean")
    a.lat_mod=a.lat_mod.fillna(grp_means2)
    a["gps_height_mod"]=a["gps_height"]
    a.loc[a['gps_height_mod'] == 0, 'gps_height_mod'] = pd.NA
    grp_means3=a.groupby(by=["basin"])["gps_height_mod"].transform("mean")
    a.gps_height_mod=a.gps_height_mod.fillna(grp_means3)
    a.wpt_name=a.wpt_name.str.lower()
    x=list(a.wpt_name.value_counts()[(a.wpt_name.value_counts().values==1)].index)
    a.wpt_name=a.wpt_name.replace(x,"single")
    #subvillage
    grp_mode4=a.groupby(by=["region"])["subvillage"].transform(lambda x: x.mode().iloc[0])
    a.subvillage=a.subvillage.fillna(grp_mode4)
    y=list(a.subvillage.value_counts()[(a.subvillage.value_counts().values==1)].index)
    a.subvillage=a.subvillage.replace(y,"single")
    a.public_meeting=a.public_meeting.fillna("True")
    grp_mode5=a.groupby(by=["region"])["permit"].transform(lambda x: x.mode().iloc[0])
    a.permit=a.permit.fillna(grp_mode5)
    grp_mode6=a.groupby(by=["region"])["scheme_management"].transform(lambda x: x.mode().iloc[0])
    a.scheme_management=a.scheme_management.fillna(grp_mode6)
    a["permit"]=a["permit"].map(lambda s: "T" if s==True else("F" if s== False else "M"))
    a["public_meeting"]=a["public_meeting"].map(lambda s: "T" if s==True else("F" if s== False else "M"))
    #bin_edges=[np.min(a.gps_height)-1,0,500,1000,1500,2000,np.max(a.gps_height)]
    #bin_labels=["<0","0-500","500-1000","1000-1500","1500-2000",">2000"]
    #a["gps_height_cat"]=pd.cut(a.gps_height,bins=bin_edges,labels=bin_labels).astype("O")
    a=a.drop(["id","recorded_by","scheme_name","num_private"],axis=1)
    a["amount_tsh_cat"] = a["amount_tsh"].apply(lambda x: 0 if x == 0 else 1)
    date_format = '%Y-%m-%d'
    a["date_recorded"]=pd.to_datetime(a["date_recorded"])
    a["dsr"]=pd.to_datetime("2023-11-16")-a["date_recorded"]
    a.dsr=(a.dsr/ pd.Timedelta(seconds=86400))
    bin_edges=[np.min(a.construction_year)-1,0,1961,1971,1981,1991,2001,np.max(a.construction_year)+1]
    bin_labels=["0","0-1960","1960-70","1970-80","1980-90","1990-2000","2001-2013"]
    a["construction_year_cat"]=pd.cut(a.construction_year,bins=bin_edges,labels=bin_labels).astype("O")
    a=a.drop(["amount_tsh","date_recorded","gps_height","latitude","longitude","construction_year"],axis=1)
    a[["region_code","district_code","amount_tsh_cat"]]=a[["region_code","district_code","amount_tsh_cat"]].astype("O")
    cat=a.select_dtypes(include="O").columns
    #a[cat] = a[cat].fillna('missing')
    a[["region_code","district_code","amount_tsh_cat"]]=a[["region_code","district_code","amount_tsh_cat"]].astype("O")
    return a

# %%
Target1=process_target2(Target1)

# %%
Target1
# Out:
#                        funder   installer  wpt_name                    basin  \
# 0                        dmdd        dmdd    single                 Internal
# 1      government of tanzania         dwe    single                  Pangani
# 2                        tcrs        sema    single                 Internal
# 3                  finn water  finn water    single  Ruvuma / Southern Coast
# 4                      bruder      bruder    single  Ruvuma / Southern Coast
# ...                       ...         ...       ...                      ...
# 14845                  danida          da    single              Wami / Ruvu
# 14846                    hiap        hiap    single                  Pangani
# 14847                    tcrs        sema   bwawani                 Internal
# 14848                 germany         dwe  kwa john               Lake Nyasa
# 14849  government of tanzania  government    single               Lake Nyasa
#
#         subvillage   region region_code district_code            lga  \
# 0           Magoma  Manyara          21             3          Mbulu
# 1           single   Arusha           2             2   Arusha Rural
# 2           single  Singida          13             2  Singida Rural
# 3       Kipindimbi    Lindi          80            43         Liwale
# 4          Losonga   Ruvuma          10             3         Mbinga
# ...            ...      ...         ...           ...            ...
# 14845        Yombo    Pwani           6             1       Bagamoyo
# 14846      Mkondoa    Tanga           4             7        Kilindi
# 14847       Juhudi  Singida          13             2  Singida Rural
# 14848  Namakinga B   Ruvuma          10             2   Songea Rural
# 14849       single   Ruvuma          10             3         Mbinga
#
#                ward  ...           source_type source_class  \
# 0            Bashay  ...  rainwater harvesting      surface
# 1          Kimnyaki  ...                spring  groundwater
# 2              Puma  ...  rainwater harvesting      surface
# 3           Mkutano  ...          shallow well  groundwater
# 4      Mbinga Urban  ...                spring  groundwater
# ...             ...  ...                   ...          ...
# 14845         Yombo  ...            river/lake      surface
# 14846       Mvungwe  ...          shallow well  groundwater
# 14847       Ughandi  ...                   dam      surface
# 14848      Maposeni  ...            river/lake      surface
# 14849    Mbamba bay  ...                spring  groundwater
#
#           waterpoint_type waterpoint_type_group   long_mod    lat_mod  \
# 0                   other                 other  35.290799  -4.059696
# 1      communal standpipe    communal standpipe  36.656709  -3.309214
# 2                   other                 other  34.767863  -5.004344
# 3                   other                 other  38.058046  -9.418672
# 4      communal standpipe    communal standpipe  35.006123 -10.950412
# ...                   ...                   ...        ...        ...
# 14845  communal standpipe    communal standpipe  38.852669  -6.582841
# 14846           hand pump             hand pump  37.451633  -5.350428
# 14847  communal standpipe    communal standpipe  34.739804  -4.585587
# 14848  communal standpipe    communal standpipe  35.432732 -10.584159
# 14849  communal standpipe    communal standpipe  34.765054 -11.226012
#
#       gps_height_mod amount_tsh_cat     dsr construction_year_cat
# 0         1996.00000              0  3937.0             2001-2013
# 1         1569.00000              0  3937.0             1990-2000
# 2         1567.00000              0  3940.0             2001-2013
# 3          267.00000              0  3950.0               1980-90
# 4         1260.00000              1  3886.0             1990-2000
# ...              ...            ...     ...                   ...
# 14845       34.00000              0  4648.0               1980-90
# 14846     1082.02754              1  4623.0             1990-2000
# 14847     1476.00000              0  3909.0             2001-2013
# 14848      998.00000              0  3923.0             2001-2013
# 14849      481.00000              0  3928.0             2001-2013
#
# [14850 rows x 36 columns]

# %%
Target1[Label_col]=Or.transform(Target1[Label_col])

# %%
Target1
# Out:
#        funder  installer  wpt_name  basin  subvillage  region  region_code  \
# 0        79.0       88.0    2740.0    0.0      3409.0     8.0         20.0
# 1       114.0       91.0    2740.0    5.0      7338.0     0.0          1.0
# 2       353.0      321.0    2740.0    0.0      7338.0    18.0         12.0
# 3       100.0      104.0    2740.0    7.0      2432.0     7.0         24.0
# 4        30.0       30.0    2740.0    7.0        -1.0    16.0          9.0
# ...       ...        ...       ...    ...         ...     ...          ...
# 14845    64.0       71.0    2740.0    8.0      7300.0    14.0          5.0
# 14846    -1.0       -1.0    2740.0    5.0      4438.0    20.0          3.0
# 14847   353.0      321.0     108.0    0.0      1559.0    18.0         12.0
# 14848   109.0       91.0     932.0    1.0      5421.0    16.0          9.0
# 14849   114.0      119.0    2740.0    1.0      7338.0    16.0          9.0
#
#        district_code    lga    ward  ...  source_type  source_class  \
# 0                3.0   63.0    18.0  ...          3.0           1.0
# 1                2.0    0.0   689.0  ...          6.0           0.0
# 2                2.0  108.0  1774.0  ...          3.0           1.0
# 3               13.0   49.0  1272.0  ...          5.0           0.0
# 4                3.0   61.0  1148.0  ...          6.0           0.0
# ...              ...    ...     ...  ...          ...           ...
# 14845            1.0    3.0  2062.0  ...          4.0           1.0
# 14846            7.0   33.0  1442.0  ...          5.0           0.0
# 14847            2.0  108.0  1976.0  ...          1.0           1.0
# 14848            2.0  110.0  1063.0  ...          4.0           1.0
# 14849            3.0   61.0  1135.0  ...          6.0           0.0
#
#        waterpoint_type  waterpoint_type_group   long_mod    lat_mod  \
# 0                  6.0                    5.0  35.290799  -4.059696
# 1                  1.0                    1.0  36.656709  -3.309214
# 2                  6.0                    5.0  34.767863  -5.004344
# 3                  6.0                    5.0  38.058046  -9.418672
# 4                  1.0                    1.0  35.006123 -10.950412
# ...                ...                    ...        ...        ...
# 14845              1.0                    1.0  38.852669  -6.582841
# 14846              4.0                    3.0  37.451633  -5.350428
# 14847              1.0                    1.0  34.739804  -4.585587
# 14848              1.0                    1.0  35.432732 -10.584159
# 14849              1.0                    1.0  34.765054 -11.226012
#
#        gps_height_mod  amount_tsh_cat     dsr  construction_year_cat
# 0          1996.00000             0.0  3937.0                    6.0
# 1          1569.00000             0.0  3937.0                    5.0
# 2          1567.00000             0.0  3940.0                    6.0
# 3           267.00000             0.0  3950.0                    4.0
# 4          1260.00000             1.0  3886.0                    5.0
# ...               ...             ...     ...                    ...
# 14845        34.00000             0.0  4648.0                    4.0
# 14846      1082.02754             1.0  4623.0                    5.0
# 14847      1476.00000             0.0  3909.0                    6.0
# 14848       998.00000             0.0  3923.0                    6.0
# 14849       481.00000             0.0  3928.0                    6.0
#
# [14850 rows x 36 columns]

# %%
y_pred=clf_xg.predict(Target1)
y_pred=le.inverse_transform(y_pred)

# %%
y_pred=pd.DataFrame(y_pred, columns=["status_group"])
y_pred["id"]=Target_x["id"]
y_pred=y_pred.reindex(["id","status_group"],axis=1)
y_pred.to_csv("F:/Personal/Queens MMAI/MMAI 869 – Machine Learning and AI Technology/Driven Data team Assignment/Xgboost 14.12.2023.csv",index=False)
